# %%
# %%capture 
# !pip install boto3 requests pandas pyarrow

# %%
import io
import os
import requests
import pandas as pd
import boto3
from pandas import DataFrame
import pandas as pd
from pyarrow import fs
import pyarrow.parquet as pq
import pyarrow as pa
from dotenv import load_dotenv
"""
Pre-reqs: 
1. `pip install pandas pyarrow boto3`
2. Set AWS_ACCESS_KEY_ID and AWS_SECRET_ACCESS_KEY in your environment variables or use boto3 configuration method
3. Set your S3 bucket name as BUCKET
"""
load_dotenv()


# services = ['fhv','green','yellow']
#init_url = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/'
init_url = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv'
BUCKET = os.getenv("S3_BUCKET_NAME")

 # Ensure BUCKET variable is a string and print its value
if not isinstance(BUCKET, str):
    raise TypeError("BUCKET variable is not a string.")
print("Bucket:", BUCKET)
        
def upload_to_s3(bucket, object_name, local_file):
    """
    Uploads a file to S3 bucket
    """
    s3_client = boto3.client('s3')
    s3_client.upload_file(local_file, bucket, object_name)

def web_to_s3(year, service):
    for i in range(12):
        # sets the month part of the file_name string
        month = f"{i+1:02d}"

        # csv file_name
        file_name = f"{service}_tripdata_{year}-{month}.csv.gz"

        # download it using requests via a pandas df
#         request_url = f"{init_url}{service}/{file_name}"
        request_url = f"{init_url}/{file_name}"
        r = requests.get(request_url)
        open(file_name, 'wb').write(r.content)
        print(f"Local: {file_name}")
        print(f"Link : {request_url}")
        # read it back into a parquet file
        df = pd.read_csv(file_name, compression='gzip')
        parquet_file_name = file_name.replace('.csv.gz', '.parquet')
        df.to_parquet(parquet_file_name, engine='pyarrow')
        print(f"Parquet: {parquet_file_name}")

        # upload it to S3 
        upload_to_s3(BUCKET, f"{service}/{parquet_file_name}", parquet_file_name)
        print(f"S3: {service}/{parquet_file_name}")
# https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-01.csv.gz

# web_to_s3('2019', 'green')
# web_to_s3('2020', 'green')
# web_to_s3('2019', 'yellow')
# web_to_s3('2020', 'yellow')
web_to_s3('2019', 'fhv')
web_to_s3('2020', 'fhv')
# Out:
# Bucket: magetaxi-project
# Local: fhv_tripdata_2019-01.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-01.csv.gz
# Parquet: fhv_tripdata_2019-01.parquet
# S3: fhv/fhv_tripdata_2019-01.parquet
# Local: fhv_tripdata_2019-02.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-02.csv.gz
# Parquet: fhv_tripdata_2019-02.parquet
# S3: fhv/fhv_tripdata_2019-02.parquet
# Local: fhv_tripdata_2019-03.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-03.csv.gz
# Parquet: fhv_tripdata_2019-03.parquet
# S3: fhv/fhv_tripdata_2019-03.parquet
# Local: fhv_tripdata_2019-04.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-04.csv.gz
# Parquet: fhv_tripdata_2019-04.parquet
# S3: fhv/fhv_tripdata_2019-04.parquet
# Local: fhv_tripdata_2019-05.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-05.csv.gz
# Parquet: fhv_tripdata_2019-05.parquet
# S3: fhv/fhv_tripdata_2019-05.parquet
# Local: fhv_tripdata_2019-06.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-06.csv.gz
# Parquet: fhv_tripdata_2019-06.parquet
# S3: fhv/fhv_tripdata_2019-06.parquet
# Local: fhv_tripdata_2019-07.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-07.csv.gz
# Parquet: fhv_tripdata_2019-07.parquet
# S3: fhv/fhv_tripdata_2019-07.parquet
# Local: fhv_tripdata_2019-08.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-08.csv.gz
# Parquet: fhv_tripdata_2019-08.parquet
# S3: fhv/fhv_tripdata_2019-08.parquet
# Local: fhv_tripdata_2019-09.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-09.csv.gz
# Parquet: fhv_tripdata_2019-09.parquet
# S3: fhv/fhv_tripdata_2019-09.parquet
# Local: fhv_tripdata_2019-10.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-10.csv.gz
# Parquet: fhv_tripdata_2019-10.parquet
# S3: fhv/fhv_tripdata_2019-10.parquet
# Local: fhv_tripdata_2019-11.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-11.csv.gz
# Parquet: fhv_tripdata_2019-11.parquet
# S3: fhv/fhv_tripdata_2019-11.parquet
# Local: fhv_tripdata_2019-12.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2019-12.csv.gz
# Parquet: fhv_tripdata_2019-12.parquet
# S3: fhv/fhv_tripdata_2019-12.parquet
# Local: fhv_tripdata_2020-01.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2020-01.csv.gz
# Parquet: fhv_tripdata_2020-01.parquet
# S3: fhv/fhv_tripdata_2020-01.parquet
# Local: fhv_tripdata_2020-02.csv.gz
# Link : https://github.com/DataTalksClub/nyc-tlc-data/releases/download/fhv/fhv_tripdata_2020-02.csv.gz
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8220/182477138.py in <module>
#      67 # web_to_s3('2020', 'yellow')
#      68 web_to_s3('2019', 'fhv')
# ---> 69 web_to_s3('2020', 'fhv')
#
# ~\AppData\Local\Temp/ipykernel_8220/182477138.py in web_to_s3(year, service)
#      52         print(f"Link : {request_url}")
#      53         # read it back into a parquet file
# ---> 54         df = pd.read_csv(file_name, compression='gzip')
#      55         parquet_file_name = file_name.replace('.csv.gz', '.parquet')
#      56         df.to_parquet(parquet_file_name, engine='pyarrow')
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     222         try:
#     223             if self.low_memory:
# --> 224                 chunks = self._reader.read_low_memory(nrows)
#     225                 # destructive to chunks
#     226                 data = _concatenate_chunks(chunks)
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~\anaconda3\envs\brainiac\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 41721: invalid start byte
